# %%
# importing packages

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import math
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler

# %%
# uploading dataframe from EDA

df = pd.read_csv('Cleaned_Life_Expectancy_Data.csv')

# %%
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2883     Zimbabwe  2004  Developing              44.3            723.0
# 2884     Zimbabwe  2003  Developing              44.5            715.0
# 2885     Zimbabwe  2002  Developing              44.8             73.0
# 2886     Zimbabwe  2001  Developing              45.3            686.0
# 2887     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Measles    BMI   \
# 0                62     0.01               71.279624      1154   19.1
# 1                64     0.01               73.523582       492   18.6
# 2                66     0.01               73.219243       430   18.1
# 3                69     0.01               78.184215      2787   17.6
# 4                71     0.01                7.097109      3013   17.2
# ...             ...      ...                     ...       ...    ...
# 2883             27     4.36                0.000000        31   27.1
# 2884             26     4.06                0.000000       998   26.7
# 2885             25     4.43                0.000000       304   26.3
# 2886             25     1.72                0.000000       529   25.9
# 2887             24     1.68                0.000000      1483   25.5
#
#       under-five deaths   Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# 0                     83    6.0               8.16         65.0        0.1
# 1                     86   58.0               8.18         62.0        0.1
# 2                     89   62.0               8.13         64.0        0.1
# 3                     93   67.0               8.52         67.0        0.1
# 4                     97   68.0               7.87         68.0        0.1
# ...                  ...    ...                ...          ...        ...
# 2883                  42   67.0               7.13         65.0       33.6
# 2884                  41    7.0               6.52         68.0       36.7
# 2885                  40   73.0               6.53         71.0       39.8
# 2886                  39   76.0               6.16         75.0       42.1
# 2887                  39   78.0               7.10         78.0       43.5
#
#        thinness  1-19 years   thinness 5-9 years  \
# 0                      17.2                 17.3
# 1                      17.5                 17.5
# 2                      17.7                 17.7
# 3                      17.9                 18.0
# 4                      18.2                 18.2
# ...                     ...                  ...
# 2883                    9.4                  9.4
# 2884                    9.8                  9.9
# 2885                    1.2                  1.3
# 2886                    1.6                  1.7
# 2887                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2883                            0.407        9.2
# 2884                            0.418        9.5
# 2885                            0.427       10.0
# 2886                            0.427        9.8
# 2887                            0.434        9.8
#
# [2888 rows x 19 columns]

# %% [markdown]
# # Test/Train Split

# %%
# defining our features and target
feature_cols = list(df.columns)
feature_cols.remove('Life expectancy ')

# %%
# defining our features and target
X = df[feature_cols]
y = df['Life expectancy ']

# %%
# test/train split with 80% train size/20% test size
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 155)

# %%
X_train.head()
# Out:
#                                     Country  Year      Status  \
# 1519                                  Libya  2000  Developing
# 1336                                 Jordan  2007  Developing
# 717   Democratic People's Republic of Korea  2002  Developing
# 704   Democratic People's Republic of Korea  2015  Developing
# 2257                                 Serbia  2008  Developing
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 1519            148.0              3     0.01              457.320224
# 1336             12.0              4     0.60              373.262864
# 717             167.0             14     3.08                0.000000
# 704             139.0              6     0.01                0.000000
# 2257            132.0              1     9.54               96.332379
#
#       Measles    BMI   under-five deaths   Polio  Total expenditure  \
# 1519         0   52.8                   3   94.0               3.41
# 1336        41   59.3                   4   98.0               8.35
# 717          0   26.2                  18   99.0               4.33
# 704          0   32.9                   7   99.0               4.33
# 2257         2   55.8                   1   95.0               1.50
#
#       Diphtheria    HIV/AIDS   thinness  1-19 years   thinness 5-9 years  \
# 1519         94.0        0.1                    5.7                  5.5
# 1336         98.0        0.1                    3.8                  3.8
# 717          64.0        0.1                    5.9                  5.9
# 704          96.0        0.1                    4.9                  4.9
# 2257         95.0        0.1                    2.3                  2.4
#
#       Income composition of resources  Schooling
# 1519                         0.727000  15.500000
# 1336                         0.736000  13.600000
# 717                          0.587465  11.352032
# 704                          0.587465  11.352032
# 2257                         0.749000  13.500000

# %% [markdown]
# # Feature Engineering (Complex) - Train

# %%
# feature engineering complex model
def feature_eng(df):
        df = df.copy()

        df['Status'] = df['Status'].map({'Developed':1, 'Developing':0})

        df.drop(columns = ['Country', 'Year', 'infant deaths', 'Measles ', 'Total expenditure'], inplace = True)

        return df

# %%
# applying feature engineering on X_train
X_train_fe = feature_eng(X_train)

# %%
# Scaling on X_train, using Robust scaler
rob = RobustScaler().set_output(transform="pandas")
rob.fit(X_train_fe)
X_train_fe = rob.transform(X_train_fe)

# %%
# checking data types of X_train
X_train.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
# Checking columns in X_train_fe
X_train_fe.columns
# Out:
# Index(['Status', 'Adult Mortality', 'Alcohol', 'percentage expenditure',
#        ' BMI ', 'under-five deaths ', 'Polio', 'Diphtheria ', ' HIV/AIDS',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
X_train_fe.head()
# Out:
#       Status  Adult Mortality   Alcohol  percentage expenditure      BMI   \
# 1519     0.0         0.039735 -0.515786                0.851139  0.251513
# 1336     0.0        -0.860927 -0.432068                0.668051  0.426362
# 717      0.0         0.165563 -0.080170               -0.144963 -0.464022
# 704      0.0        -0.019868 -0.515786               -0.144963 -0.283793
# 2257     0.0        -0.066225  0.836467                0.064861  0.332213
#
#       under-five deaths      Polio  Diphtheria    HIV/AIDS  \
# 1519           -0.037037  0.052632     0.052632        0.0
# 1336            0.000000  0.263158     0.263158        0.0
# 717             0.518519  0.315789    -1.526316        0.0
# 704             0.111111  0.315789     0.157895        0.0
# 2257           -0.111111  0.105263     0.105263        0.0
#
#        thinness  1-19 years   thinness 5-9 years  \
# 1519               0.436364             0.385965
# 1336               0.090909             0.087719
# 717                0.472727             0.456140
# 704                0.290909             0.280702
# 2257              -0.181818            -0.157895
#
#       Income composition of resources  Schooling
# 1519                         0.194030   0.820513
# 1336                         0.227612   0.333333
# 717                         -0.326623  -0.243069
# 704                         -0.326623  -0.243069
# 2257                         0.276119   0.307692

# %%
# initialising, fitting and predicting linear regression using SK learn

lin_reg = LinearRegression()

lin_reg.fit(X_train_fe, y_train)

y_pred = lin_reg.predict(X_train_fe)

metrics.mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 4.064691430035102

# %% [markdown]
# # Feature Engineering (Complex) - Test

# %%
# applying feature engineering to X_test
X_test_fe = feature_eng(X_test)

# %%
# applying scaling to X_test_fe
X_test_fe = rob.transform(X_test_fe)

# %%
X_test_fe.head()
# Out:
#       Status  Adult Mortality   Alcohol  percentage expenditure      BMI   \
# 308      0.0         0.370861  0.040440               -0.144963  0.173504
# 916      0.0        -0.370861  0.874778                0.009720 -0.991258
# 538      0.0        -0.635762 -0.457609               -0.125499 -0.754539
# 1536     1.0        -0.523179  1.060660               -0.144963  0.480161
# 129      1.0        -0.503311  1.230933               18.042827  0.367182
#
#       under-five deaths      Polio  Diphtheria    HIV/AIDS  \
# 308             0.259259  0.105263     0.105263   0.166667
# 916            -0.148148  0.315789     0.315789   0.000000
# 538             2.777778 -2.947368    -3.578947   8.500000
# 1536           -0.148148  0.315789     0.315789   0.000000
# 129            -0.148148  0.263158     0.263158   0.000000
#
#        thinness  1-19 years   thinness 5-9 years  \
# 308               -0.381818            -0.385965
# 916               -0.436364            -0.438596
# 538               -0.327273            -0.333333
# 1536              -0.418182            -0.421053
# 129               -0.272727            -0.228070
#
#       Income composition of resources  Schooling
# 308                         -0.097015   0.384615
# 916                          0.757463   1.179487
# 538                         -1.376866  -1.717949
# 1536                         0.824627   0.410256
# 129                          0.809701   0.923077

# %%
# Calculating the RMSE of the complex model

y_pred_test = lin_reg.predict(X_test_fe)

RMSE = metrics.mean_squared_error(y_test, y_pred_test, squared=False)

print(f'The RMSE of our complex model {RMSE}')
# Out:
# The RMSE of our complex model 4.180115338556166

# %% [markdown]
# # Feature Engineering (Simple/Data Sensitive) - Train

# %%
# checking the columns of the the data frame
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Measles ',
#        ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
# feature engineering the simple model

def feature_eng_simple(df):
        df = df.copy()

        df['Status'] = df['Status'].map({'Developed':1, 'Developing':0}).astype(float)

        df.drop(columns = ['Country', 'Year', 'infant deaths', 'Measles ', 'Total expenditure',' BMI ', 'Adult Mortality', 'Alcohol', 'percentage expenditure', 'under-five deaths ', 'Polio', 'Diphtheria ', ' HIV/AIDS', ' thinness  1-19 years', ' thinness 5-9 years'], inplace = True)

        return df

# %%
# applying feature engineering to X_train
X_train_fe_simple = feature_eng_simple(X_train)

# %%
# applying scaling to X_train_fe_simple with Robust Scaler
rob = RobustScaler().set_output(transform="pandas")
rob.fit(X_train_fe_simple)
X_train_fe_simple = rob.transform(X_train_fe_simple)

# %%
X_train_fe_simple.head()
# Out:
#       Status  Income composition of resources  Schooling
# 1519     0.0                         0.194030   0.820513
# 1336     0.0                         0.227612   0.333333
# 717      0.0                        -0.326623  -0.243069
# 704      0.0                        -0.326623  -0.243069
# 2257     0.0                         0.276119   0.307692

# %%
# initialising, fitting and predicting linear regression using SK learn

lin_reg_simple = LinearRegression()

lin_reg_simple.fit(X_train_fe_simple, y_train)

y_pred_simple = lin_reg_simple.predict(X_train_fe_simple)

metrics.mean_squared_error(y_train, y_pred_simple, squared=False)
# Out:
# 6.066801951438528

# %% [markdown]
# # Feature Engineering (Simple/Data Sensitive) - Test

# %%
X_test_fe_simple = feature_eng_simple(X_test)

# %%
X_test_fe_simple = rob.transform(X_test_fe_simple)

# %%
X_test_fe_simple.head()
# Out:
#       Status  Income composition of resources  Schooling
# 308      0.0                        -0.097015   0.384615
# 916      0.0                         0.757463   1.179487
# 538      0.0                        -1.376866  -1.717949
# 1536     1.0                         0.824627   0.410256
# 129      1.0                         0.809701   0.923077

# %%
y_pred_test_simple = lin_reg_simple.predict(X_test_fe_simple)

RMSE_simple = metrics.mean_squared_error(y_test, y_pred_test_simple, squared=False)

print(f'The RMSE of our simple model {RMSE_simple}')
# Out:
# The RMSE of our simple model 5.9307621234637615

# %% [markdown]
# # Making a copy

# %%
FEATURE ENGINEERING - WHO PROJECT GROUP 3.ipynb
